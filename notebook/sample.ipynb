# %% [markdown]
# # Sample Notebook
#
# Verify that the project package can be imported.

# %%
from sample_project.resolvers import register_resolvers
from sample_project.meta import collect_meta

print("import ok")
# Out:
# import ok

# %%
register_resolvers()
print("resolvers registered")
# Out:
# resolvers registered

# %%
meta = collect_meta()
meta
# Out:
# {'timestamp': '2026-02-18T01:45:19.797582+00:00',
#  'git': {'branch': 'main',
#   'commit': 'f2cf4589be507cc6935887b77c29755fbf041f80',
#   'dirty': False}}
